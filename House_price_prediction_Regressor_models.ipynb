# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df=pd.read_csv('/content/kc_house_data.csv')

# %%
df
# Out:
#                id             date  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  20141013T000000         3       1.00         1180
# 1      6414100192  20141209T000000         3       2.25         2570
# 2      5631500400  20150225T000000         2       1.00          770
# 3      2487200875  20141209T000000         4       3.00         1960
# 4      1954400510  20150218T000000         3       2.00         1680
# ...           ...              ...       ...        ...          ...
# 21608   263000018  20140521T000000         3       2.50         1530
# 21609  6600060120  20150223T000000         4       2.50         2310
# 21610  1523300141  20140623T000000         2       0.75         1020
# 21611   291310100  20150116T000000         3       2.50         1600
# 21612  1523300157  20141015T000000         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  condition  ...  sqft_above  \
# ...

# %%
df.drop(['date'],axis=1 , inplace= True)

# %%
df
# Out:
#                id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      7129300520         3       1.00         1180      5650     1.0
# 1      6414100192         3       2.25         2570      7242     2.0
# 2      5631500400         2       1.00          770     10000     1.0
# 3      2487200875         4       3.00         1960      5000     1.0
# 4      1954400510         3       2.00         1680      8080     1.0
# ...           ...       ...        ...          ...       ...     ...
# 21608   263000018         3       2.50         1530      1131     3.0
# 21609  6600060120         4       2.50         2310      5813     2.0
# 21610  1523300141         2       0.75         1020      1350     2.0
# 21611   291310100         3       2.50         1600      2388     2.0
# 21612  1523300157         2       0.75         1020      1076     2.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# ...

# %%
df.corr()
# Out:
#                      id  bedrooms  bathrooms  sqft_living  sqft_lot    floors  \
# id             1.000000  0.001286   0.005160    -0.012258 -0.132109  0.018525
# bedrooms       0.001286  1.000000   0.515884     0.576671  0.031703  0.175429
# bathrooms      0.005160  0.515884   1.000000     0.754665  0.087740  0.500653
# sqft_living   -0.012258  0.576671   0.754665     1.000000  0.172826  0.353949
# sqft_lot      -0.132109  0.031703   0.087740     0.172826  1.000000 -0.005201
# floors         0.018525  0.175429   0.500653     0.353949 -0.005201  1.000000
# waterfront    -0.002721 -0.006582   0.063744     0.103818  0.021604  0.023698
# view           0.011592  0.079532   0.187737     0.284611  0.074710  0.029444
# condition     -0.023783  0.028472  -0.124982    -0.058753 -0.008958 -0.263768
# grade          0.008130  0.356967   0.664983     0.762704  0.113621  0.458183
# sqft_above    -0.010842  0.477600   0.685342     0.876597  0.183512  0.523885
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   bedrooms       21613 non-null  int64
#  2   bathrooms      21613 non-null  float64
#  3   sqft_living    21613 non-null  int64
#  4   sqft_lot       21613 non-null  int64
#  5   floors         21613 non-null  float64
#  6   waterfront     21613 non-null  int64
#  7   view           21613 non-null  int64
#  8   condition      21613 non-null  int64
#  9   grade          21613 non-null  int64
#  10  sqft_above     21613 non-null  int64
#  11  sqft_basement  21613 non-null  int64
#  12  yr_built       21613 non-null  int64
#  13  yr_renovated   21613 non-null  int64
#  14  zipcode        21613 non-null  int64
#  15  lat            21613 non-null  float64
#  16  long           21613 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# id               0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# price            0
# dtype: int64

# %% [markdown]
# # Simple Linear regression

# %%
X= df.iloc[:,9:10].values
X
# Out:
# array([[7],
#        [7],
#        [6],
#        ...,
#        [7],
#        [8],
#        [7]])

# %%
y= df.iloc[:,-1].values
y
# Out:
# array([221900., 538000., 180000., ..., 402101., 400000., 325000.])

# %% [markdown]
# # Splitting Dataset into Training & Testing set

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %% [markdown]
# # Training Simple Linear Model on Training Set

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # Predicting the Test set result

# %%
y_pred=regressor.predict(X_test)
y_pred
# Out:
# array([ 404310.6017, 1454122.8442,  404310.6017, ...,  404310.6017,
#         194348.1532,  404310.6017])

# %%
y_test
# Out:
# array([ 297000., 1580000.,  562100., ...,  369950.,  300000.,  575950.])

# %%
from sklearn.metrics import r2_score
print(r2_score(y_test,y_pred))
# Out:
# 0.4735213014212426

# %% [markdown]
# # Multiple Linear Regression

# %%
df.corr()
# Out:
#                      id  bedrooms  bathrooms  sqft_living  sqft_lot    floors  \
# id             1.000000  0.001286   0.005160    -0.012258 -0.132109  0.018525
# bedrooms       0.001286  1.000000   0.515884     0.576671  0.031703  0.175429
# bathrooms      0.005160  0.515884   1.000000     0.754665  0.087740  0.500653
# sqft_living   -0.012258  0.576671   0.754665     1.000000  0.172826  0.353949
# sqft_lot      -0.132109  0.031703   0.087740     0.172826  1.000000 -0.005201
# floors         0.018525  0.175429   0.500653     0.353949 -0.005201  1.000000
# waterfront    -0.002721 -0.006582   0.063744     0.103818  0.021604  0.023698
# view           0.011592  0.079532   0.187737     0.284611  0.074710  0.029444
# condition     -0.023783  0.028472  -0.124982    -0.058753 -0.008958 -0.263768
# grade          0.008130  0.356967   0.664983     0.762704  0.113621  0.458183
# sqft_above    -0.010842  0.477600   0.685342     0.876597  0.183512  0.523885
# ...

# %%
# d= df.drop(['sqft_living', 'sqft_lot15','sqft_basement','id', 'yr_built', 'yr_renovated', 'zipcode', 'waterfront', 'view', 'condition', 'lat', 'long'],axis=1)
# d
d= df.drop(['id','zipcode'],axis=1)
d
# Out:
#        bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0             3       1.00         1180      5650     1.0           0     0
# 1             3       2.25         2570      7242     2.0           0     0
# 2             2       1.00          770     10000     1.0           0     0
# 3             4       3.00         1960      5000     1.0           0     0
# 4             3       2.00         1680      8080     1.0           0     0
# ...         ...        ...          ...       ...     ...         ...   ...
# 21608         3       2.50         1530      1131     3.0           0     0
# 21609         4       2.50         2310      5813     2.0           0     0
# 21610         2       0.75         1020      1350     2.0           0     0
# 21611         3       2.50         1600      2388     2.0           0     0
# 21612         2       0.75         1020      1076     2.0           0     0
#
# ...

# %%
X= d.iloc[:,:-1].values
X
# Out:
# array([[ 3.0000e+00,  1.0000e+00,  1.1800e+03, ..., -1.2226e+02,
#          1.3400e+03,  5.6500e+03],
#        [ 3.0000e+00,  2.2500e+00,  2.5700e+03, ..., -1.2232e+02,
#          1.6900e+03,  7.6390e+03],
#        [ 2.0000e+00,  1.0000e+00,  7.7000e+02, ..., -1.2223e+02,
#          2.7200e+03,  8.0620e+03],
#        ...,
#        [ 2.0000e+00,  7.5000e-01,  1.0200e+03, ..., -1.2230e+02,
#          1.0200e+03,  2.0070e+03],
#        [ 3.0000e+00,  2.5000e+00,  1.6000e+03, ..., -1.2207e+02,
#          1.4100e+03,  1.2870e+03],
#        [ 2.0000e+00,  7.5000e-01,  1.0200e+03, ..., -1.2230e+02,
#          1.0200e+03,  1.3570e+03]])

# %%
y= d.iloc[:,-1].values
y
# Out:
# array([221900., 538000., 180000., ..., 402101., 400000., 325000.])

# %% [markdown]
# # Splitting dataset into Train set and Test set

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= 0.2, random_state=0)

# %%
from sklearn.linear_model import LinearRegression
regressor= LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # Predicting Test Set results

# %%
y_pred = regressor.predict(X_test)
np.set_printoptions(precision=4) #decimal number 4 tk when(precision=4)
np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1)
# Out:
# array([[ 380823.8246,  297000.    ],
#        [1519888.367 , 1580000.    ],
#        [ 528888.0661,  562100.    ],
#        ...,
#        [ 345297.3938,  369950.    ],
#        [ 197342.8138,  300000.    ],
#        [ 399948.7002,  575950.    ]])

# %%
from sklearn.metrics import r2_score
print(r2_score(y_test,y_pred))
# Out:
# 0.68895880595263

# %% [markdown]
# # Polynomial Regressor

# %%
X= d.iloc[:,1:-1].values
X
# Out:
# array([[ 1.0000e+00,  1.1800e+03,  5.6500e+03, ..., -1.2226e+02,
#          1.3400e+03,  5.6500e+03],
#        [ 2.2500e+00,  2.5700e+03,  7.2420e+03, ..., -1.2232e+02,
#          1.6900e+03,  7.6390e+03],
#        [ 1.0000e+00,  7.7000e+02,  1.0000e+04, ..., -1.2223e+02,
#          2.7200e+03,  8.0620e+03],
#        ...,
#        [ 7.5000e-01,  1.0200e+03,  1.3500e+03, ..., -1.2230e+02,
#          1.0200e+03,  2.0070e+03],
#        [ 2.5000e+00,  1.6000e+03,  2.3880e+03, ..., -1.2207e+02,
#          1.4100e+03,  1.2870e+03],
#        [ 7.5000e-01,  1.0200e+03,  1.0760e+03, ..., -1.2230e+02,
#          1.0200e+03,  1.3570e+03]])

# %%
y= d.iloc[:,-1].values
y
# Out:
# array([221900., 538000., 180000., ..., 402101., 400000., 325000.])

# %% [markdown]
# # Training Linear Regression Model

# %%
from sklearn.linear_model import LinearRegression
lin_reg= LinearRegression()
lin_reg.fit(X,y)
# Out:
# LinearRegression()

# %% [markdown]
# # Training Polynomial Regression Model

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg= PolynomialFeatures(degree=2)
X_poly= poly_reg.fit_transform(X)

# %%
X
# Out:
# array([[ 1.0000e+00,  1.1800e+03,  5.6500e+03, ..., -1.2226e+02,
#          1.3400e+03,  5.6500e+03],
#        [ 2.2500e+00,  2.5700e+03,  7.2420e+03, ..., -1.2232e+02,
#          1.6900e+03,  7.6390e+03],
#        [ 1.0000e+00,  7.7000e+02,  1.0000e+04, ..., -1.2223e+02,
#          2.7200e+03,  8.0620e+03],
#        ...,
#        [ 7.5000e-01,  1.0200e+03,  1.3500e+03, ..., -1.2230e+02,
#          1.0200e+03,  2.0070e+03],
#        [ 2.5000e+00,  1.6000e+03,  2.3880e+03, ..., -1.2207e+02,
#          1.4100e+03,  1.2870e+03],
#        [ 7.5000e-01,  1.0200e+03,  1.0760e+03, ..., -1.2230e+02,
#          1.0200e+03,  1.3570e+03]])

# %%
X_poly
# Out:
# array([[1.0000e+00, 1.0000e+00, 1.1800e+03, ..., 1.7956e+06, 7.5710e+06,
#         3.1922e+07],
#        [1.0000e+00, 2.2500e+00, 2.5700e+03, ..., 2.8561e+06, 1.2910e+07,
#         5.8354e+07],
#        [1.0000e+00, 1.0000e+00, 7.7000e+02, ..., 7.3984e+06, 2.1929e+07,
#         6.4996e+07],
#        ...,
#        [1.0000e+00, 7.5000e-01, 1.0200e+03, ..., 1.0404e+06, 2.0471e+06,
#         4.0280e+06],
#        [1.0000e+00, 2.5000e+00, 1.6000e+03, ..., 1.9881e+06, 1.8147e+06,
#         1.6564e+06],
#        [1.0000e+00, 7.5000e-01, 1.0200e+03, ..., 1.0404e+06, 1.3841e+06,
#         1.8414e+06]])

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test= train_test_split(X_poly,y,test_size=0.2,random_state=0)

# %%
lin_reg2= LinearRegression()
lin_reg2.fit(X_poly,y)
# Out:
# LinearRegression()

# %%
lin_reg2.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred= lin_reg2.predict(X_test)

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.7869694397918191

# %% [markdown]
# # SVR

# %%
X
# Out:
# array([[ 3.0000e+00,  1.0000e+00,  1.1800e+03, ..., -1.2226e+02,
#          1.3400e+03,  5.6500e+03],
#        [ 3.0000e+00,  2.2500e+00,  2.5700e+03, ..., -1.2232e+02,
#          1.6900e+03,  7.6390e+03],
#        [ 2.0000e+00,  1.0000e+00,  7.7000e+02, ..., -1.2223e+02,
#          2.7200e+03,  8.0620e+03],
#        ...,
#        [ 2.0000e+00,  7.5000e-01,  1.0200e+03, ..., -1.2230e+02,
#          1.0200e+03,  2.0070e+03],
#        [ 3.0000e+00,  2.5000e+00,  1.6000e+03, ..., -1.2207e+02,
#          1.4100e+03,  1.2870e+03],
#        [ 2.0000e+00,  7.5000e-01,  1.0200e+03, ..., -1.2230e+02,
#          1.0200e+03,  1.3570e+03]])

# %%
y
# Out:
# array([221900., 538000., 180000., ..., 402101., 400000., 325000.])

# %%
X.shape
# Out:
# (21613, 16)

# %%
y.shape
# Out:
# (21613,)

# %%
y=y.reshape(len(y),1)

# %%
y
# Out:
# array([[221900.],
#        [538000.],
#        [180000.],
#        ...,
#        [402101.],
#        [400000.],
#        [325000.]])

# %% [markdown]
# # Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
sc_x=StandardScaler()
X=sc_x.fit_transform(X)

sc_y=StandardScaler()
y=sc_y.fit_transform(y)

# %%
X
# Out:
# array([[-1.4475, -0.9798, -0.2283, ..., -0.3061, -0.9434, -0.2607],
#        [ 0.1756,  0.5336, -0.1899, ..., -0.7463, -0.4327, -0.1879],
#        [-1.4475, -1.4263, -0.1233, ..., -0.1357,  1.0701, -0.1724],
#        ...,
#        [-1.7721, -1.154 , -0.3321, ..., -0.6043, -1.4103, -0.3941],
#        [ 0.5002, -0.5225, -0.3071, ...,  1.0289, -0.8412, -0.4205],
#        [-1.7721, -1.154 , -0.3388, ..., -0.6043, -1.4103, -0.4179]])

# %%
y
# Out:
# array([[-0.8664],
#        [-0.0059],
#        [-0.9805],
#        ...,
#        [-0.3759],
#        [-0.3816],
#        [-0.5858]])

# %% [markdown]
# # Training SVR model on dataset

# %%
from sklearn.svm import SVR
regressor=SVR(kernel='rbf')
regressor.fit(X,y)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVR()

# %%
X
# Out:
# array([[-1.4475, -0.9798, -0.2283, ..., -0.3061, -0.9434, -0.2607],
#        [ 0.1756,  0.5336, -0.1899, ..., -0.7463, -0.4327, -0.1879],
#        [-1.4475, -1.4263, -0.1233, ..., -0.1357,  1.0701, -0.1724],
#        ...,
#        [-1.7721, -1.154 , -0.3321, ..., -0.6043, -1.4103, -0.3941],
#        [ 0.5002, -0.5225, -0.3071, ...,  1.0289, -0.8412, -0.4205],
#        [-1.7721, -1.154 , -0.3388, ..., -0.6043, -1.4103, -0.4179]])

# %%
y
# Out:
# array([[-0.8664],
#        [-0.0059],
#        [-0.9805],
#        ...,
#        [-0.3759],
#        [-0.3816],
#        [-0.5858]])

# %%
y_pred=regressor.predict(X)
y_pred
# Out:
# array([-0.6924,  0.1658, -0.4278, ..., -0.605 , -0.2923, -0.6106])

# %%
y_test=sc_y.inverse_transform(y)
y_test
# Out:
# array([[221900.],
#        [538000.],
#        [180000.],
#        ...,
#        [402101.],
#        [400000.],
#        [325000.]])

# %%
from sklearn.metrics import r2_score
r2_score(y,y_pred)
# Out:
# 0.8128822465034027

# %% [markdown]
# # Decision Tree Regressor

# %%
X= d.iloc[:,:-1].values
X
# Out:
# array([[ 3.0000e+00,  1.0000e+00,  1.1800e+03, ..., -1.2226e+02,
#          1.3400e+03,  5.6500e+03],
#        [ 3.0000e+00,  2.2500e+00,  2.5700e+03, ..., -1.2232e+02,
#          1.6900e+03,  7.6390e+03],
#        [ 2.0000e+00,  1.0000e+00,  7.7000e+02, ..., -1.2223e+02,
#          2.7200e+03,  8.0620e+03],
#        ...,
#        [ 2.0000e+00,  7.5000e-01,  1.0200e+03, ..., -1.2230e+02,
#          1.0200e+03,  2.0070e+03],
#        [ 3.0000e+00,  2.5000e+00,  1.6000e+03, ..., -1.2207e+02,
#          1.4100e+03,  1.2870e+03],
#        [ 2.0000e+00,  7.5000e-01,  1.0200e+03, ..., -1.2230e+02,
#          1.0200e+03,  1.3570e+03]])

# %%
y=  d.iloc[:,-1].values
y
# Out:
# array([221900., 538000., 180000., ..., 402101., 400000., 325000.])

# %% [markdown]
# #Training Decision Tree Model

# %%
from sklearn.tree import DecisionTreeRegressor
regressor= DecisionTreeRegressor(random_state=0)
regressor.fit(X,y)
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
from sklearn.metrics import r2_score
r2_score(y,regressor.predict(X))
# Out:
# 0.9991345917455311

# %% [markdown]
# #Random Forest Regressor

# %%
X= d.iloc[:,1:-1].values
X
# Out:
# array([[ 1.0000e+00,  1.1800e+03,  5.6500e+03, ..., -1.2226e+02,
#          1.3400e+03,  5.6500e+03],
#        [ 2.2500e+00,  2.5700e+03,  7.2420e+03, ..., -1.2232e+02,
#          1.6900e+03,  7.6390e+03],
#        [ 1.0000e+00,  7.7000e+02,  1.0000e+04, ..., -1.2223e+02,
#          2.7200e+03,  8.0620e+03],
#        ...,
#        [ 7.5000e-01,  1.0200e+03,  1.3500e+03, ..., -1.2230e+02,
#          1.0200e+03,  2.0070e+03],
#        [ 2.5000e+00,  1.6000e+03,  2.3880e+03, ..., -1.2207e+02,
#          1.4100e+03,  1.2870e+03],
#        [ 7.5000e-01,  1.0200e+03,  1.0760e+03, ..., -1.2230e+02,
#          1.0200e+03,  1.3570e+03]])

# %%
y= d.iloc[:,-1].values
y
# Out:
# array([221900., 538000., 180000., ..., 402101., 400000., 325000.])

# %% [markdown]
# ##Training Random Forest model

# %%
from sklearn.ensemble import RandomForestRegressor
regressor= RandomForestRegressor(n_estimators=10, random_state=0)
regressor.fit(X,y)
# Out:
# RandomForestRegressor(n_estimators=10, random_state=0)

# %%
from sklearn.metrics import r2_score
r2_score(y,regressor.predict(X))
# Out:
# 0.9739614821985265

# %%
accuracy= {
    "Linear Regression": 0.4735213014212426,
    "Polynomial Regression":  0.7869694397918191,
    "SVR": 0.8128822465034027,
    "Decision Tree Regressor": 0.9991345917455311,
    "Random Forest Regressor": 0.9739614821985265
    }

# %%
Series = pd.Series(accuracy)
Series
# Out:
# Linear Regression          0.473521
# Polynomial Regression      0.786969
# SVR                        0.812882
# Decision Tree Regressor    0.999135
# Random Forest Regressor    0.973961
# dtype: float64
